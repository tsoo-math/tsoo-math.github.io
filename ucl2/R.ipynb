# %% [markdown]
# # Using R inside Jupyter
#
# You may need to install the package from a command line prompt (as an admin)
# * conda install -c r r-irkernel
#
# Now when you choose a new Juptyer notebook, the R option should be available.  Below, we will run R code.

# %%
x <- runif(10000)
y <- runif(10000)
z = x+y
hist(z, prob=T)
# Out:
# Plot with title "Histogram of z"
